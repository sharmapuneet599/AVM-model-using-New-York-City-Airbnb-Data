# %% [markdown]
# # Automated Valuation Model (AVM)
# ## Project - Building an AVM model using New York City Airbnb Data
# In this notebook, I will be exploring the [New York City Airbnb Open Dataset](https://www.kaggle.com/dgomonov/new-york-city-airbnb-open-data) from Kaggle and building a model that can predict their corresponding prices.
#
# This projects requires the following libraries :
# - [Pandas](https://pandas.pydata.org)
# - [Numpy](https://numpy.org)
# - [Keras](https://keras.io/)
# - [Sklearn](https://scikit-learn.org/)
#
# **Please ensure you have installed the following libraries mentioned above before continuing.**

# %% [markdown]
# ### Importing the Necessary libraries

# %%
import numpy as np
import pandas as pd
from keras.callbacks import ModelCheckpoint
from keras.models import Sequential
from keras.layers import Dense, Activation, Flatten
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
from keras.layers import LeakyReLU
from sklearn import preprocessing
from sklearn.metrics import mean_squared_error
from math import sqrt
# Out:
# Using TensorFlow backend.
# c:\python 3.6\lib\site-packages\tensorflow\python\framework\dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# c:\python 3.6\lib\site-packages\tensorflow\python\framework\dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# c:\python 3.6\lib\site-packages\tensorflow\python\framework\dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# c:\python 3.6\lib\site-packages\tensorflow\python\framework\dtypes.py:529: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# c:\python 3.6\lib\site-packages\tensorflow\python\framework\dtypes.py:530: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# c:\python 3.6\lib\site-packages\tensorflow\python\framework\dtypes.py:535: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %% [markdown]
# ### Loading Data
# Pandas is a great open source library providing high-performance, easy-to-use data structures and data analysis tools for the Python. So we will be using it in the project to visualize and modifying the dataset according to out needs.

# %%
# Loading Dataset
Data = pd.read_csv(r'C:\Users\sharm\OneDrive\Desktop\ML project\new-york-city-airbnb-open-data\AB_NYC_2019.csv')

# Checking the number of training examples in Dataset
print('Size of Dataset:', len(Data))

#looking over the dataset
Data[:5]
# Out:
# Size of Dataset: 48895
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# 0     Private room    149               1                  9  2018-10-19
# 1  Entire home/apt    225               1                 45  2019-05-21
# 2     Private room    150               3                  0         NaN
# 3  Entire home/apt     89               1                270  2019-07-05
# 4  Entire home/apt     80              10                  9  2018-11-19
#
#    reviews_per_month  calculated_host_listings_count  availability_365
# 0               0.21                               6               365
# 1               0.38                               2               355
# 2                NaN                               1               365
# 3               4.64                               1               194
# 4               0.10                               1                 0

# %% [markdown]
# ## Data Preprocessing
# Data preprocessing is a data mining technique that involves transforming raw data into an understandable format. Real-world data is often incomplete, inconsistent, and/or lacking in certain behaviors or trends, and is likely to contain many errors. Data preprocessing is a proven method of resolving such issues.
#
# We will be checking and resolving the following before feeding the data into model:
# - Checking for null values if any (fill them with zeroes or average value of that feature)
# - Dropping the Feature that are not necessary in model learning (like id, it is unique for every datapoint)
# - Checking the Datatypes of every Feature and if it's not *int* or *float* then **Encode** them because model cant learns on numerics.
# - Distribute the Dataset into Features and Labels.
# - Normalizing the Dataset. It change the values of numeric columns in the dataset to use a common scale, without distorting differences in the ranges of values or losing information. For more information on Normalization see [this](https://www.quora.com/Why-do-we-normalize-the-data).
# - Distributing the Dataset into Training and Testing Subsets.

# %%
# Checking if there any null values are present or not
Data.isnull().sum()
# Out:
# id                                    0
# name                                 16
# host_id                               0
# host_name                            21
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10052
# reviews_per_month                 10052
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %%
# Filling the empty values with mean of that feature
Data.fillna({'reviews_per_month':Data['reviews_per_month'].mean()}, inplace=True)
# Examing changes
Data.reviews_per_month.isnull().sum()
# Out:
# 0

# %%
# Dropping the unnecessary features
Data.drop(['id','host_name','last_review','name', 'host_id'], axis=1, inplace=True)

# %% [markdown]
# Encoding Features using Label Encoding. For details see [this example](https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.LabelEncoder.html#sklearn-preprocessing-labelencoder).

# %%
# Encoding 'neighbourhood_group' feature
E = preprocessing.LabelEncoder()
E.fit(Data['neighbourhood_group'])
encoded = E.transform(Data['neighbourhood_group'])
Data.drop(['neighbourhood_group'], axis=1, inplace=True)
Data['neighbourhood_group'] = encoded

# %%
# Encoding 'room_type' feature
E.fit(Data['room_type'])
encoded = E.transform(Data['room_type'])
Data.drop(['room_type'], axis=1, inplace=True)
Data['room_type'] = encoded

# %%
# Encoding 'neighbourhood' feature
E.fit(Data['neighbourhood'])
encoded = E.transform(Data['neighbourhood'])
Data.drop(['neighbourhood'], axis=1, inplace=True)
Data['neighbourhood'] = encoded

# %%
# Checking the mean to know if there is need to normalize the Dataset 
Data.mean(axis = 0)
# Out:
# latitude                           40.728949
# longitude                         -73.952170
# price                             152.720687
# minimum_nights                      7.029962
# number_of_reviews                  23.274466
# reviews_per_month                   1.373221
# calculated_host_listings_count      7.143982
# availability_365                  112.781327
# neighbourhood_group                 1.675345
# room_type                           0.504060
# neighbourhood                     107.122732
# dtype: float64

# %% [markdown]
# ### Normalizing Dataset
# We will be normalizing the Features using [StandardScaler](https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.StandardScaler.html#sklearn-preprocessing-standardscaler) of `sklearn`. The standard score of a sample x is calculated as: `z = (x - u) / s` where `x` is the feature, `u` is the mean and `s` is the standard deviation. For example of StandardScaler see [this](http://benalexkeen.com/feature-scaling-with-scikit-learn/).

# %%
# Dividing the dataset into features and labels
prices = Data['price']
features = Data.drop('price', axis = 1)

# Normalizing the Features
scaler = preprocessing.StandardScaler()
scaled_df = scaler.fit_transform(features)
scaled_df = pd.DataFrame(scaled_df, columns=['latitude', 'longitude',  'minimum_nights', 'number_of_reviews',
                                            'reviews_per_month', 'calculated_host_listings_count', 'availability_365', 
                                             'neighbourhood_group', 'room_type', 'neighbourhood'])

# %% [markdown]
# ### Splitting the Dataset into Training and Testing Subsets
# The data we use is usually split into training data and test data.The training set contains a known output and the model learns on this data in order to be generalized to other data later on. We have the test dataset (or subset) in order to test our model’s prediction on this subset.

# %%
# Shuffle and split the data into training and testing subsets
X_train, X_test, y_train, y_test = train_test_split(scaled_df , prices , test_size=0.05 , random_state=0)

# %%
# Visualizing Dataset Before feeding into Model
scaled_df[:5]
# Out:
#    latitude  longitude  minimum_nights  number_of_reviews  reviews_per_month  \
# 0 -1.493849  -0.437652       -0.293996          -0.320414          -0.776641
# 1  0.452436  -0.684639       -0.293996           0.487665          -0.663138
# 2  1.468399   0.222497       -0.196484          -0.522433           0.000000
# 3 -0.803398  -0.164450       -0.293996           5.538156           2.181110
# 4  1.275660   0.177216        0.144807          -0.320414          -0.850084
#
#    calculated_host_listings_count  availability_365  neighbourhood_group  \
# 0                       -0.034716          1.916250            -0.917828
# 1                       -0.156104          1.840275             0.441222
# 2                       -0.186451          1.916250             0.441222
# 3                       -0.186451          0.617065            -0.917828
# 4                       -0.186451         -0.856865             0.441222
#
#    room_type  neighbourhood
# 0   0.909359       0.012762
# 1  -0.924247       0.289156
# 2   0.909359      -0.190897
# 3  -0.924247      -0.961892
# 4  -0.924247      -0.670950

# %% [markdown]
# ## Defining our own Network Architecture
# Here comes the main part of this project. All the cool and magical stuff happens here. We will use Deep neural networks. A Deep neural network (DNN) is an artificial neural network (ANN) with multiple layers between the input and output layers. The DNN finds the correct mathematical manipulation to turn the input into the output, whether it be a linear relationship or a non-linear relationship. The network moves through the layers calculating the probability of each output. For more details see [this](https://www.techopedia.com/definition/32902/deep-neural-network).
#
#
# We will be needing some activation functions. Now you might be thinking what are activation Function, they are used to introduce non-linearity to our model. For more details see [this](https://towardsdatascience.com/activation-functions-and-its-types-which-is-better-a9a5310cc8f). So we will also be using [Leaky reLu](https://medium.com/@danqing/a-practical-guide-to-relu-b83ca804f1f7) as our activaiton function. We will be building a 6 layer Deep Neural Network.

# %%
model = Sequential()
# The Input Layer :
model.add(Dense(32, kernel_initializer='normal',input_dim = X_train.shape[1], activation='relu'))

# The Hidden Layers :
model.add(Dense(64, kernel_initializer='normal'))
model.add(LeakyReLU(alpha=0.05))
model.add(Dense(128, kernel_initializer='normal'))
model.add(LeakyReLU(alpha=0.05))
model.add(Dense(128, kernel_initializer='normal'))
model.add(LeakyReLU(alpha=0.05))
model.add(Dense(64, kernel_initializer='normal'))
model.add(LeakyReLU(alpha=0.05))
# The Output Layer :
model.add(Dense(1, kernel_initializer='normal',activation='linear'))

# Compile the network :
model.compile(loss='mean_absolute_error', optimizer='adam')
model.summary()
# Out:
# WARNING:tensorflow:From c:\python 3.6\lib\site-packages\tensorflow\python\ops\resource_variable_ops.py:435: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 32)                352
# _________________________________________________________________
# dense_2 (Dense)              (None, 64)                2112
# _________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)    (None, 64)                0
# _________________________________________________________________
# dense_3 (Dense)              (None, 128)               8320
# _________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)    (None, 128)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 128)               16512
# _________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)    (None, 128)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 64)                8256
# _________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)    (None, 64)                0
# _________________________________________________________________
# dense_6 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 35,617
# Trainable params: 35,617
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Defining [Loss Function](https://keras.io/losses/) and [Optimizer](https://keras.io/optimizers/) and Training the model
# We will be using `mean_absolute_error` as our **loss** function and `adam` as our **optimizer**.

# %%
# Creating checkpoints Everytime the new best validation Loss is encountered
checkpoint_name = 'Weights.hdf5' 
checkpoint = ModelCheckpoint(checkpoint_name, monitor='val_loss', verbose = 1, save_best_only = True, mode ='auto')
callbacks_list = [checkpoint]
model.fit(X_train, y_train, epochs=250, batch_size=5, validation_split = 0.2, callbacks=callbacks_list)
# Out:
# WARNING:tensorflow:From c:\python 3.6\lib\site-packages\tensorflow\python\ops\math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Train on 37160 samples, validate on 9290 samples
# Epoch 1/250
# 37160/37160 [==============================] - 7s 197us/step - loss: 63.5596 - val_loss: 59.9517
#
# Epoch 00001: val_loss improved from inf to 59.95170, saving model to Weights.hdf5
# Epoch 2/250
# 37160/37160 [==============================] - 7s 194us/step - loss: 61.2030 - val_loss: 62.0227
#
# Epoch 00002: val_loss did not improve from 59.95170
# Epoch 3/250
# 37160/37160 [==============================] - 7s 193us/step - loss: 60.6759 - val_loss: 57.7679
#
# Epoch 00003: val_loss improved from 59.95170 to 57.76789, saving model to Weights.hdf5
# Epoch 4/250
# 37160/37160 [==============================] - 8s 202us/step - loss: 60.4465 - val_loss: 57.6728
#
# Epoch 00004: val_loss improved from 57.76789 to 57.67282, saving model to Weights.hdf5
# Epoch 5/250
# 37160/37160 [==============================] - 9s 241us/step - loss: 60.1729 - val_loss: 58.3462
#
# Epoch 00005: val_loss did not improve from 57.67282
# Epoch 6/250
# 37160/37160 [==============================] - 8s 216us/step - loss: 59.9100 - val_loss: 57.5238
#
# Epoch 00006: val_loss improved from 57.67282 to 57.52375, saving model to Weights.hdf5
# Epoch 7/250
# 37160/37160 [==============================] - 7s 195us/step - loss: 59.8048 - val_loss: 57.9649
#
# Epoch 00007: val_loss did not improve from 57.52375
# Epoch 8/250
# 37160/37160 [==============================] - 8s 203us/step - loss: 59.7644 - val_loss: 57.5280
#
# Epoch 00008: val_loss did not improve from 57.52375
# Epoch 9/250
# 37160/37160 [==============================] - 10s 266us/step - loss: 59.5889 - val_loss: 57.4878
#
# Epoch 00009: val_loss improved from 57.52375 to 57.48777, saving model to Weights.hdf5
# Epoch 10/250
# 37160/37160 [==============================] - 7s 199us/step - loss: 59.5324 - val_loss: 57.3369
#
# Epoch 00010: val_loss improved from 57.48777 to 57.33685, saving model to Weights.hdf5
# Epoch 11/250
# 37160/37160 [==============================] - 7s 183us/step - loss: 59.4439 - val_loss: 57.2284
#
# Epoch 00011: val_loss improved from 57.33685 to 57.22841, saving model to Weights.hdf5
# Epoch 12/250
# 37160/37160 [==============================] - 7s 197us/step - loss: 59.3618 - val_loss: 57.2742
#
# Epoch 00012: val_loss did not improve from 57.22841
# Epoch 13/250
# 37160/37160 [==============================] - 8s 208us/step - loss: 59.3244 - val_loss: 57.4007
#
# Epoch 00013: val_loss did not improve from 57.22841
# Epoch 14/250
# 37160/37160 [==============================] - 8s 216us/step - loss: 59.2224 - val_loss: 57.0015
#
# Epoch 00014: val_loss improved from 57.22841 to 57.00153, saving model to Weights.hdf5
# Epoch 15/250
# 37160/37160 [==============================] - 7s 195us/step - loss: 59.1037 - val_loss: 57.1747
#
# Epoch 00015: val_loss did not improve from 57.00153
# Epoch 16/250
# 37160/37160 [==============================] - 8s 204us/step - loss: 59.0776 - val_loss: 58.0396
#
# Epoch 00016: val_loss did not improve from 57.00153
# Epoch 17/250
# 37160/37160 [==============================] - 7s 200us/step - loss: 59.0422 - val_loss: 57.7766
#
# Epoch 00017: val_loss did not improve from 57.00153
# Epoch 18/250
# 37160/37160 [==============================] - 7s 185us/step - loss: 58.9539 - val_loss: 57.5652
#
# Epoch 00018: val_loss did not improve from 57.00153
# Epoch 19/250
# 37160/37160 [==============================] - 7s 182us/step - loss: 58.9057 - val_loss: 57.2413
#
# Epoch 00019: val_loss did not improve from 57.00153
# Epoch 20/250
# 37160/37160 [==============================] - 7s 181us/step - loss: 58.7502 - val_loss: 57.2861
#
# Epoch 00020: val_loss did not improve from 57.00153
# Epoch 21/250
# 37160/37160 [==============================] - 7s 182us/step - loss: 58.5741 - val_loss: 57.6056
#
# Epoch 00021: val_loss did not improve from 57.00153
# Epoch 22/250
# 37160/37160 [==============================] - 7s 181us/step - loss: 58.5176 - val_loss: 57.5596
#
# Epoch 00022: val_loss did not improve from 57.00153
# Epoch 23/250
# 37160/37160 [==============================] - 7s 187us/step - loss: 58.4155 - val_loss: 56.8989
#
# Epoch 00023: val_loss improved from 57.00153 to 56.89886, saving model to Weights.hdf5
# Epoch 24/250
# 37160/37160 [==============================] - 7s 184us/step - loss: 58.3493 - val_loss: 57.9201
#
# Epoch 00024: val_loss did not improve from 56.89886
# Epoch 25/250
# 37160/37160 [==============================] - 7s 181us/step - loss: 58.2995 - val_loss: 56.9204
#
# Epoch 00025: val_loss did not improve from 56.89886
# Epoch 26/250
# 37160/37160 [==============================] - 7s 181us/step - loss: 58.2232 - val_loss: 56.8413
#
# Epoch 00026: val_loss improved from 56.89886 to 56.84125, saving model to Weights.hdf5
# Epoch 27/250
# 37160/37160 [==============================] - 7s 181us/step - loss: 58.2400 - val_loss: 57.7523
#
# Epoch 00027: val_loss did not improve from 56.84125
# Epoch 28/250
# 37160/37160 [==============================] - 8s 206us/step - loss: 58.1475 - val_loss: 56.8980
#
# Epoch 00028: val_loss did not improve from 56.84125
# Epoch 29/250
# 37160/37160 [==============================] - 9s 242us/step - loss: 58.1521 - val_loss: 56.5996
#
# Epoch 00029: val_loss improved from 56.84125 to 56.59961, saving model to Weights.hdf5
# Epoch 30/250
# 37160/37160 [==============================] - 8s 213us/step - loss: 58.0696 - val_loss: 57.8521
#
# Epoch 00030: val_loss did not improve from 56.59961
# Epoch 31/250
# 37160/37160 [==============================] - 6s 175us/step - loss: 58.0833 - val_loss: 58.2540
#
# Epoch 00031: val_loss did not improve from 56.59961
# Epoch 32/250
# 37160/37160 [==============================] - 7s 176us/step - loss: 57.9334 - val_loss: 56.4684
#
# Epoch 00032: val_loss improved from 56.59961 to 56.46836, saving model to Weights.hdf5
# Epoch 33/250
# 37160/37160 [==============================] - 7s 177us/step - loss: 57.9096 - val_loss: 57.7897
#
# Epoch 00033: val_loss did not improve from 56.46836
# Epoch 34/250
# 37160/37160 [==============================] - 7s 183us/step - loss: 57.8811 - val_loss: 56.5891
#
# Epoch 00034: val_loss did not improve from 56.46836
# Epoch 35/250
# 37160/37160 [==============================] - 8s 205us/step - loss: 57.8830 - val_loss: 56.5034
#
# Epoch 00035: val_loss did not improve from 56.46836
# Epoch 36/250
# 37160/37160 [==============================] - 8s 221us/step - loss: 57.8719 - val_loss: 56.6941
#
# Epoch 00036: val_loss did not improve from 56.46836
# Epoch 37/250
# 37160/37160 [==============================] - 7s 189us/step - loss: 57.8332 - val_loss: 56.5478
#
# Epoch 00037: val_loss did not improve from 56.46836
# Epoch 38/250
# 37160/37160 [==============================] - 7s 182us/step - loss: 57.7617 - val_loss: 56.4568
#
# Epoch 00038: val_loss improved from 56.46836 to 56.45679, saving model to Weights.hdf5
# Epoch 39/250
# 37160/37160 [==============================] - 8s 214us/step - loss: 57.6756 - val_loss: 56.4749
#
# Epoch 00039: val_loss did not improve from 56.45679
# Epoch 40/250
# 37160/37160 [==============================] - 6s 173us/step - loss: 57.6819 - val_loss: 56.5116
#
# Epoch 00040: val_loss did not improve from 56.45679
# Epoch 41/250
# 37160/37160 [==============================] - 6s 175us/step - loss: 57.6401 - val_loss: 56.5969
#
# Epoch 00041: val_loss did not improve from 56.45679
# Epoch 42/250
# 37160/37160 [==============================] - 6s 173us/step - loss: 57.6611 - val_loss: 57.2523
#
# Epoch 00042: val_loss did not improve from 56.45679
# Epoch 43/250
# 37160/37160 [==============================] - 6s 172us/step - loss: 57.6077 - val_loss: 56.5384
#
# Epoch 00043: val_loss did not improve from 56.45679
# Epoch 44/250
# 37160/37160 [==============================] - 7s 201us/step - loss: 57.5082 - val_loss: 56.6263
#
# Epoch 00044: val_loss did not improve from 56.45679
# Epoch 45/250
# 37160/37160 [==============================] - 6s 173us/step - loss: 57.5585 - val_loss: 56.9542
#
# Epoch 00045: val_loss did not improve from 56.45679
# Epoch 46/250
# 37160/37160 [==============================] - 7s 177us/step - loss: 57.4569 - val_loss: 56.5100
#
# Epoch 00046: val_loss did not improve from 56.45679
# Epoch 47/250
# 37160/37160 [==============================] - 6s 171us/step - loss: 57.4789 - val_loss: 56.9013
#
# Epoch 00047: val_loss did not improve from 56.45679
# Epoch 48/250
# 37160/37160 [==============================] - 8s 202us/step - loss: 57.3927 - val_loss: 56.5625
#
# Epoch 00048: val_loss did not improve from 56.45679
# Epoch 49/250
# 37160/37160 [==============================] - 8s 205us/step - loss: 57.2873 - val_loss: 57.1343
#
# Epoch 00049: val_loss did not improve from 56.45679
# Epoch 50/250
# 37160/37160 [==============================] - 7s 179us/step - loss: 57.2871 - val_loss: 56.5086
#
# Epoch 00050: val_loss did not improve from 56.45679
# Epoch 51/250
# 37160/37160 [==============================] - 7s 177us/step - loss: 57.3835 - val_loss: 56.5149
#
# Epoch 00051: val_loss did not improve from 56.45679
# Epoch 52/250
# 37160/37160 [==============================] - 6s 175us/step - loss: 57.3141 - val_loss: 56.5291
#
# Epoch 00052: val_loss did not improve from 56.45679
# Epoch 53/250
# 37160/37160 [==============================] - 6s 172us/step - loss: 57.1018 - val_loss: 56.1759
#
# Epoch 00053: val_loss improved from 56.45679 to 56.17592, saving model to Weights.hdf5
# Epoch 54/250
# 37160/37160 [==============================] - 8s 215us/step - loss: 57.1746 - val_loss: 56.6122
#
# Epoch 00054: val_loss did not improve from 56.17592
# Epoch 55/250
# 37160/37160 [==============================] - 8s 221us/step - loss: 57.1068 - val_loss: 56.5418
#
# Epoch 00055: val_loss did not improve from 56.17592
# Epoch 56/250
# 37160/37160 [==============================] - 7s 183us/step - loss: 57.0646 - val_loss: 56.2371
#
# Epoch 00056: val_loss did not improve from 56.17592
# Epoch 57/250
# 37160/37160 [==============================] - 8s 219us/step - loss: 56.9904 - val_loss: 56.7105
#
# Epoch 00057: val_loss did not improve from 56.17592
# Epoch 58/250
# 37160/37160 [==============================] - 7s 199us/step - loss: 57.0070 - val_loss: 57.1011
#
# Epoch 00058: val_loss did not improve from 56.17592
# Epoch 59/250
# 37160/37160 [==============================] - 7s 176us/step - loss: 56.9309 - val_loss: 56.3332
#
# Epoch 00059: val_loss did not improve from 56.17592
# Epoch 60/250
# 37160/37160 [==============================] - 10s 265us/step - loss: 56.9636 - val_loss: 57.8976
#
# Epoch 00060: val_loss did not improve from 56.17592
# Epoch 61/250
# 37160/37160 [==============================] - 8s 204us/step - loss: 56.8553 - val_loss: 56.2571
#
# Epoch 00061: val_loss did not improve from 56.17592
# Epoch 62/250
# 37160/37160 [==============================] - 8s 222us/step - loss: 56.8572 - val_loss: 56.0988
#
# Epoch 00062: val_loss improved from 56.17592 to 56.09882, saving model to Weights.hdf5
# Epoch 63/250
# 37160/37160 [==============================] - 7s 197us/step - loss: 56.7610 - val_loss: 56.6926
#
# Epoch 00063: val_loss did not improve from 56.09882
# Epoch 64/250
# 37160/37160 [==============================] - 8s 203us/step - loss: 56.6934 - val_loss: 58.2439
#
# Epoch 00064: val_loss did not improve from 56.09882
# Epoch 65/250
# 37160/37160 [==============================] - 8s 204us/step - loss: 56.6375 - val_loss: 56.8661
#
# Epoch 00065: val_loss did not improve from 56.09882
# Epoch 66/250
# 37160/37160 [==============================] - 7s 196us/step - loss: 56.6384 - val_loss: 56.1205
#
# Epoch 00066: val_loss did not improve from 56.09882
# Epoch 67/250
# 37160/37160 [==============================] - 8s 215us/step - loss: 56.6084 - val_loss: 56.1559
#
# Epoch 00067: val_loss did not improve from 56.09882
# Epoch 68/250
# 37160/37160 [==============================] - 8s 212us/step - loss: 56.6096 - val_loss: 57.9578
#
# Epoch 00068: val_loss did not improve from 56.09882
# Epoch 69/250
# 37160/37160 [==============================] - 7s 188us/step - loss: 56.5308 - val_loss: 56.3094
#
# Epoch 00069: val_loss did not improve from 56.09882
# Epoch 70/250
# 37160/37160 [==============================] - 11s 292us/step - loss: 56.5861 - val_loss: 56.1462
#
# Epoch 00070: val_loss did not improve from 56.09882
# Epoch 71/250
# 37160/37160 [==============================] - 11s 296us/step - loss: 56.4591 - val_loss: 55.7679
#
# Epoch 00071: val_loss improved from 56.09882 to 55.76785, saving model to Weights.hdf5
# Epoch 72/250
# 37160/37160 [==============================] - 7s 176us/step - loss: 56.5535 - val_loss: 55.9746
#
# Epoch 00072: val_loss did not improve from 55.76785
# Epoch 73/250
# 37160/37160 [==============================] - 7s 186us/step - loss: 56.4083 - val_loss: 55.5821
#
# Epoch 00073: val_loss improved from 55.76785 to 55.58209, saving model to Weights.hdf5
# Epoch 74/250
# 37160/37160 [==============================] - 7s 190us/step - loss: 56.2603 - val_loss: 55.9954
#
# Epoch 00074: val_loss did not improve from 55.58209
# Epoch 75/250
# 37160/37160 [==============================] - 7s 181us/step - loss: 56.3701 - val_loss: 56.1418
#
# Epoch 00075: val_loss did not improve from 55.58209
# Epoch 76/250
# 37160/37160 [==============================] - 7s 178us/step - loss: 56.3668 - val_loss: 55.8101
#
# Epoch 00076: val_loss did not improve from 55.58209
# Epoch 77/250
# 37160/37160 [==============================] - 7s 179us/step - loss: 56.2539 - val_loss: 56.7126
#
# Epoch 00077: val_loss did not improve from 55.58209
# Epoch 78/250
# 37160/37160 [==============================] - 7s 188us/step - loss: 56.3461 - val_loss: 55.7224
#
# Epoch 00078: val_loss did not improve from 55.58209
# Epoch 79/250
# 37160/37160 [==============================] - 7s 180us/step - loss: 56.2050 - val_loss: 55.7107
#
# Epoch 00079: val_loss did not improve from 55.58209
# Epoch 80/250
# 37160/37160 [==============================] - 7s 182us/step - loss: 56.1295 - val_loss: 55.8642
#
# Epoch 00080: val_loss did not improve from 55.58209
# Epoch 81/250
# 37160/37160 [==============================] - 6s 174us/step - loss: 56.2736 - val_loss: 55.7428
#
# Epoch 00081: val_loss did not improve from 55.58209
# Epoch 82/250
# 37160/37160 [==============================] - 7s 183us/step - loss: 56.0171 - val_loss: 55.8515
#
# Epoch 00082: val_loss did not improve from 55.58209
# Epoch 83/250
# 37160/37160 [==============================] - 7s 191us/step - loss: 55.9573 - val_loss: 55.7814
#
# Epoch 00083: val_loss did not improve from 55.58209
# Epoch 84/250
# 37160/37160 [==============================] - 6s 171us/step - loss: 55.9678 - val_loss: 56.1700
#
# Epoch 00084: val_loss did not improve from 55.58209
# Epoch 85/250
# 37160/37160 [==============================] - 6s 170us/step - loss: 55.9793 - val_loss: 56.0100
#
# Epoch 00085: val_loss did not improve from 55.58209
# Epoch 86/250
# 37160/37160 [==============================] - 6s 171us/step - loss: 56.0000 - val_loss: 56.1116
#
# Epoch 00086: val_loss did not improve from 55.58209
# Epoch 87/250
# 37160/37160 [==============================] - 8s 204us/step - loss: 55.8854 - val_loss: 57.0927
#
# Epoch 00087: val_loss did not improve from 55.58209
# Epoch 88/250
# 37160/37160 [==============================] - 7s 180us/step - loss: 55.9261 - val_loss: 55.8379
#
# Epoch 00088: val_loss did not improve from 55.58209
# Epoch 89/250
# 37160/37160 [==============================] - 7s 181us/step - loss: 55.8356 - val_loss: 56.5410
#
# Epoch 00089: val_loss did not improve from 55.58209
# Epoch 90/250
# 37160/37160 [==============================] - 7s 175us/step - loss: 55.7616 - val_loss: 55.7909
#
# Epoch 00090: val_loss did not improve from 55.58209
# Epoch 91/250
# 37160/37160 [==============================] - 8s 216us/step - loss: 55.8358 - val_loss: 56.1499
#
# Epoch 00091: val_loss did not improve from 55.58209
# Epoch 92/250
# 37160/37160 [==============================] - 9s 235us/step - loss: 55.7061 - val_loss: 56.0320
#
# Epoch 00092: val_loss did not improve from 55.58209
# Epoch 93/250
# 37160/37160 [==============================] - 8s 226us/step - loss: 55.7376 - val_loss: 56.1102
#
# Epoch 00093: val_loss did not improve from 55.58209
# Epoch 94/250
# 37160/37160 [==============================] - 7s 188us/step - loss: 55.8403 - val_loss: 55.7120
#
# Epoch 00094: val_loss did not improve from 55.58209
# Epoch 95/250
# 37160/37160 [==============================] - 7s 184us/step - loss: 55.7744 - val_loss: 56.0259
#
# Epoch 00095: val_loss did not improve from 55.58209
# Epoch 96/250
# 37160/37160 [==============================] - 6s 171us/step - loss: 55.6223 - val_loss: 56.2054
#
# Epoch 00096: val_loss did not improve from 55.58209
# Epoch 97/250
# 37160/37160 [==============================] - 6s 171us/step - loss: 55.6490 - val_loss: 56.1829
#
# Epoch 00097: val_loss did not improve from 55.58209
# Epoch 98/250
# 37160/37160 [==============================] - 6s 171us/step - loss: 55.5594 - val_loss: 56.3102
#
# Epoch 00098: val_loss did not improve from 55.58209
# Epoch 99/250
# 37160/37160 [==============================] - 6s 171us/step - loss: 55.5906 - val_loss: 55.8704
#
# Epoch 00099: val_loss did not improve from 55.58209
# Epoch 100/250
# 37160/37160 [==============================] - 7s 179us/step - loss: 55.5340 - val_loss: 56.5909
#
# Epoch 00100: val_loss did not improve from 55.58209
# Epoch 101/250
# 37160/37160 [==============================] - 8s 205us/step - loss: 55.5406 - val_loss: 56.0652
#
# Epoch 00101: val_loss did not improve from 55.58209
# Epoch 102/250
# 37160/37160 [==============================] - 6s 174us/step - loss: 55.4843 - val_loss: 56.4133
#
# Epoch 00102: val_loss did not improve from 55.58209
# Epoch 103/250
# 37160/37160 [==============================] - 6s 171us/step - loss: 55.4175 - val_loss: 56.2338
#
# Epoch 00103: val_loss did not improve from 55.58209
# Epoch 104/250
# 37160/37160 [==============================] - 7s 177us/step - loss: 55.4337 - val_loss: 55.9655
#
# Epoch 00104: val_loss did not improve from 55.58209
# Epoch 105/250
# 37160/37160 [==============================] - 8s 221us/step - loss: 55.4082 - val_loss: 55.8201
#
# Epoch 00105: val_loss did not improve from 55.58209
# Epoch 106/250
# 37160/37160 [==============================] - 9s 254us/step - loss: 55.4521 - val_loss: 55.5354
#
# Epoch 00106: val_loss improved from 55.58209 to 55.53545, saving model to Weights.hdf5
# Epoch 107/250
# 37160/37160 [==============================] - 8s 222us/step - loss: 55.3343 - val_loss: 56.0147
#
# Epoch 00107: val_loss did not improve from 55.53545
# Epoch 108/250
# 37160/37160 [==============================] - 8s 211us/step - loss: 55.1529 - val_loss: 56.0424
#
# Epoch 00108: val_loss did not improve from 55.53545
# Epoch 109/250
# 37160/37160 [==============================] - 8s 209us/step - loss: 55.3462 - val_loss: 55.8593
#
# Epoch 00109: val_loss did not improve from 55.53545
# Epoch 110/250
# 37160/37160 [==============================] - 7s 194us/step - loss: 55.3133 - val_loss: 56.2418
#
# Epoch 00110: val_loss did not improve from 55.53545
# Epoch 111/250
# 37160/37160 [==============================] - 7s 191us/step - loss: 55.2627 - val_loss: 56.3529
#
# Epoch 00111: val_loss did not improve from 55.53545
# Epoch 112/250
# 37160/37160 [==============================] - 7s 192us/step - loss: 55.1613 - val_loss: 56.4450
#
# Epoch 00112: val_loss did not improve from 55.53545
# Epoch 113/250
# 37160/37160 [==============================] - 7s 193us/step - loss: 55.1886 - val_loss: 55.9663
#
# Epoch 00113: val_loss did not improve from 55.53545
# Epoch 114/250
# 37160/37160 [==============================] - 7s 194us/step - loss: 55.1450 - val_loss: 55.9829
#
# Epoch 00114: val_loss did not improve from 55.53545
# Epoch 115/250
# 37160/37160 [==============================] - 7s 194us/step - loss: 54.9189 - val_loss: 55.8992
#
# Epoch 00115: val_loss did not improve from 55.53545
# Epoch 116/250
# 37160/37160 [==============================] - 7s 194us/step - loss: 55.0150 - val_loss: 55.8557
#
# Epoch 00116: val_loss did not improve from 55.53545
# Epoch 117/250
# 37160/37160 [==============================] - 7s 195us/step - loss: 55.0116 - val_loss: 56.3296
#
# Epoch 00117: val_loss did not improve from 55.53545
# Epoch 118/250
# 37160/37160 [==============================] - 7s 193us/step - loss: 55.1813 - val_loss: 56.8608
#
# Epoch 00118: val_loss did not improve from 55.53545
# Epoch 119/250
# 37160/37160 [==============================] - 7s 197us/step - loss: 54.9271 - val_loss: 57.5584
#
# Epoch 00119: val_loss did not improve from 55.53545
# Epoch 120/250
# 37160/37160 [==============================] - 7s 194us/step - loss: 54.9670 - val_loss: 56.3739
#
# Epoch 00120: val_loss did not improve from 55.53545
# Epoch 121/250
# 37160/37160 [==============================] - 7s 196us/step - loss: 55.0276 - val_loss: 55.9574
#
# Epoch 00121: val_loss did not improve from 55.53545
# Epoch 122/250
# 37160/37160 [==============================] - 9s 231us/step - loss: 54.9333 - val_loss: 56.0129
#
# Epoch 00122: val_loss did not improve from 55.53545
# Epoch 123/250
# 37160/37160 [==============================] - 8s 225us/step - loss: 54.9788 - val_loss: 56.3259
#
# Epoch 00123: val_loss did not improve from 55.53545
# Epoch 124/250
# 37160/37160 [==============================] - 7s 200us/step - loss: 54.7695 - val_loss: 56.2173
#
# Epoch 00124: val_loss did not improve from 55.53545
# Epoch 125/250
# 37160/37160 [==============================] - 8s 221us/step - loss: 54.8276 - val_loss: 56.2801
#
# Epoch 00125: val_loss did not improve from 55.53545
# Epoch 126/250
# 37160/37160 [==============================] - 7s 184us/step - loss: 54.9010 - val_loss: 55.9144
#
# Epoch 00126: val_loss did not improve from 55.53545
# Epoch 127/250
# 37160/37160 [==============================] - 7s 181us/step - loss: 54.8597 - val_loss: 56.0282
#
# Epoch 00127: val_loss did not improve from 55.53545
# Epoch 128/250
# 37160/37160 [==============================] - 7s 195us/step - loss: 54.5973 - val_loss: 56.1191
#
# Epoch 00128: val_loss did not improve from 55.53545
# Epoch 129/250
# 37160/37160 [==============================] - 7s 197us/step - loss: 54.5969 - val_loss: 55.9503
#
# Epoch 00129: val_loss did not improve from 55.53545
# Epoch 130/250
# 37160/37160 [==============================] - 7s 183us/step - loss: 54.5968 - val_loss: 56.0649
#
# Epoch 00130: val_loss did not improve from 55.53545
# Epoch 131/250
# 37160/37160 [==============================] - 7s 201us/step - loss: 54.6706 - val_loss: 55.9776
#
# Epoch 00131: val_loss did not improve from 55.53545
# Epoch 132/250
# 37160/37160 [==============================] - 7s 181us/step - loss: 54.7060 - val_loss: 55.8793
#
# Epoch 00132: val_loss did not improve from 55.53545
# Epoch 133/250
# 37160/37160 [==============================] - 7s 178us/step - loss: 54.5783 - val_loss: 56.8671
#
# Epoch 00133: val_loss did not improve from 55.53545
# Epoch 134/250
# 37160/37160 [==============================] - 7s 197us/step - loss: 54.5500 - val_loss: 55.7861
#
# Epoch 00134: val_loss did not improve from 55.53545
# Epoch 135/250
# 37160/37160 [==============================] - 7s 183us/step - loss: 54.5370 - val_loss: 56.9576
#
# Epoch 00135: val_loss did not improve from 55.53545
# Epoch 136/250
# 37160/37160 [==============================] - 7s 176us/step - loss: 54.4915 - val_loss: 56.5779
#
# Epoch 00136: val_loss did not improve from 55.53545
# Epoch 137/250
# 37160/37160 [==============================] - 6s 169us/step - loss: 54.4759 - val_loss: 56.0561
#
# Epoch 00137: val_loss did not improve from 55.53545
# Epoch 138/250
# 37160/37160 [==============================] - 7s 181us/step - loss: 54.4010 - val_loss: 56.2825
#
# Epoch 00138: val_loss did not improve from 55.53545
# Epoch 139/250
# 37160/37160 [==============================] - 7s 176us/step - loss: 54.4156 - val_loss: 56.3159
#
# Epoch 00139: val_loss did not improve from 55.53545
# Epoch 140/250
# 37160/37160 [==============================] - 7s 200us/step - loss: 54.3753 - val_loss: 55.8572
#
# Epoch 00140: val_loss did not improve from 55.53545
# Epoch 00236: val_loss did not improve from 55.53545
# Epoch 237/250
# 37160/37160 [==============================] - 6s 171us/step - loss: 52.3731 - val_loss: 56.9859
#
# Epoch 00237: val_loss did not improve from 55.53545
# Epoch 238/250
# 37160/37160 [==============================] - 7s 176us/step - loss: 52.3050 - val_loss: 57.9284
#
# Epoch 00238: val_loss did not improve from 55.53545
# Epoch 239/250
# 37160/37160 [==============================] - 6s 160us/step - loss: 52.2231 - val_loss: 56.4697
#
# Epoch 00239: val_loss did not improve from 55.53545
# Epoch 240/250
# 37160/37160 [==============================] - 6s 160us/step - loss: 52.1135 - val_loss: 57.5682
#
# Epoch 00240: val_loss did not improve from 55.53545
# Epoch 241/250
# 37160/37160 [==============================] - 6s 159us/step - loss: 52.1383 - val_loss: 56.7780
#
# Epoch 00241: val_loss did not improve from 55.53545
# Epoch 242/250
# 37160/37160 [==============================] - 6s 165us/step - loss: 52.0704 - val_loss: 57.1517
#
# Epoch 00242: val_loss did not improve from 55.53545
# Epoch 243/250
# 37160/37160 [==============================] - 6s 171us/step - loss: 51.9907 - val_loss: 57.6088
#
# Epoch 00243: val_loss did not improve from 55.53545
# Epoch 244/250
# 37160/37160 [==============================] - 6s 164us/step - loss: 52.1651 - val_loss: 57.0183
#
# Epoch 00244: val_loss did not improve from 55.53545
# Epoch 245/250
# 37160/37160 [==============================] - 6s 171us/step - loss: 52.3504 - val_loss: 56.5530
#
# Epoch 00245: val_loss did not improve from 55.53545
# Epoch 246/250
# 37160/37160 [==============================] - 6s 164us/step - loss: 52.0660 - val_loss: 57.9379
#
# Epoch 00246: val_loss did not improve from 55.53545
# Epoch 247/250
# 37160/37160 [==============================] - 6s 163us/step - loss: 52.0552 - val_loss: 57.3150
#
# Epoch 00247: val_loss did not improve from 55.53545
# Epoch 248/250
# 37160/37160 [==============================] - 6s 159us/step - loss: 51.9750 - val_loss: 56.8112
#
# Epoch 00248: val_loss did not improve from 55.53545
# Epoch 249/250
# 37160/37160 [==============================] - 6s 163us/step - loss: 51.8702 - val_loss: 57.1220
#
# Epoch 00249: val_loss did not improve from 55.53545
# Epoch 250/250
# 37160/37160 [==============================] - 6s 165us/step - loss: 52.0663 - val_loss: 56.3879
#
# Epoch 00250: val_loss did not improve from 55.53545

# %%
wights_file = 'Weights.hdf5'
# Loading the weight file with best accuracy
model.load_weights(wights_file)
model.compile(loss='mean_absolute_error', optimizer='adam', metrics=['mean_absolute_error'])

# %% [markdown]
# ## Testing
#  Predicting and Displaying some samples from original database and the one's we predicted from our model. Also showing the Root Mean Squared Error. This will be our evaluation metric. If you want to read about **RMSE** see [this](https://scikit-learn.org/stable/modules/generated/sklearn.metrics.mean_squared_error.html#sklearn-metrics-mean-squared-error).

# %%
# Predicting on the test Dataset
predictions = model.predict(X_test)

# Display prediction from model
b = predictions[1212]
print('Model Prediction of one Datapoint from Test Data:', b[0])

# Display Original Label
a = y_test.values.tolist()
print('original label from test data:', a[1212])

# Display Root Mean Squared Error
rmse = sqrt(mean_squared_error(y_test, predictions))
print('Root Mean Squared error:', rmse)
# Out:
# Model Prediction of one Datapoint from Test Data: 165.73103
# original label from test data: 179
# Root Mean Squared error: 135.44911065395334
